# %%
from google import genai

client = genai.Client(api_key="AIzaSyBy6F5A4H4DppQA6Va6oECa5TRteXwA7x0")

response = client.models.generate_content(
    model="gemini-3-pro-preview",
    contents="Find the race condition in this multi-threaded C++ snippet: [code here]",
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="AIzaSyBy6F5A4H4DppQA6Va6oECa5TRteXwA7x0")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-3-pro-preview",
#       7     contents="Find the race condition in this multi-threaded C++ snippet: [code here]",
#       8 )
#      10 print(response.text)
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/models.py:5474, in Models.generate_content(self, model, contents, config)
#    5472 while remaining_remote_calls_afc > 0:
#    5473   i += 1
# -> 5474   response = self._generate_content(
#    5475       model=model, contents=contents, config=parsed_config
#    5476   )
#    5478   function_map = _extra_utils.get_function_map(parsed_config)
#    5479   if not function_map:
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/models.py:4214, in Models._generate_content(self, model, contents, config)
#    4211 request_dict = _common.convert_to_dict(request_dict)
#    4212 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4214 response = self._api_client.request(
#    4215     'post', path, request_dict, http_options
#    4216 )
#    4218 if config is not None and getattr(
#    4219     config, 'should_return_http_response', None
#    4220 ):
#    4221   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1376 def request(
#    1377     self,
#    1378     http_method: str,
#    (...)   1381     http_options: Optional[HttpOptionsOrDict] = None,
#    1382 ) -> SdkHttpResponse:
#    1383   http_request = self._build_request(
#    1384       http_method, path, request_dict, http_options
#    1385   )
# -> 1386   response = self._request(http_request, http_options, stream=False)
#    1387   response_body = (
#    1388       response.response_stream[0] if response.response_stream else ''
#    1389   )
#    1390   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
#    1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1222 return self._retry(self._request_once, http_request, stream)
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/tenacity/__init__.py:471, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     470 while True:
# --> 471     do = self.iter(retry_state=retry_state)
#     472     if isinstance(do, DoAttempt):
#     473         try:
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/tenacity/__init__.py:372, in BaseRetrying.iter(self, retry_state)
#     370 result = None
#     371 for action in self.iter_state.actions:
# --> 372     result = action(retry_state)
#     373 return result
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/tenacity/__init__.py:414, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 retry_exc = self.retry_error_cls(fut)
#     413 if self.reraise:
# --> 414     raise retry_exc.reraise()
#     415 raise retry_exc from fut.exception()
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File ~/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/tenacity/__init__.py:474, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 if isinstance(do, DoAttempt):
#     473     try:
# --> 474         result = fn(*args, **kwargs)
#     475     except BaseException:  # noqa: B902
#     476         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1199, in BaseApiClient._request_once(self, http_request, stream)
#    1191 else:
#    1192   response = self._httpx_client.request(
#    1193       method=http_request.method,
#    1194       url=http_request.url,
#    (...)   1197       timeout=http_request.timeout,
#    1198   )
# -> 1199   errors.APIError.raise_for_response(response)
#    1200   return HttpResponse(
#    1201       response.headers, response if stream else [response.text]
#    1202   )
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/ProjectV/.venv/lib/python3.11/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)    156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3-pro\nPlease retry in 38.547485325s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'model': 'gemini-3-pro', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-3-pro', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-pro'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '38s'}]}}
